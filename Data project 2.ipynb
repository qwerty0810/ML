# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
df=pd.read_csv("C:\\Users\\sharan\\Downloads\\all_data_copy (1).csv")

# %%
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 373695   259353    AAA Batteries (4-pack)                3       2.99
# 373696   259354                    iPhone                1        700
# 373697   259355                    iPhone                1        700
# 373698   259356    34in Ultrawide Monitor                1     379.99
# 373699   259357      USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# #There are 7 coloumns in the above dataset. The first column contains serial numbers which tells us the number of products ordered.
# #The secomd column is the Order ID. The third column is the product type while the fourth column is the quantity of the product ordered.
# #The fifth column contians the total price of the order while the sixth has the order date for each order.
# #The last column contains the purchase address of the client to which the oder was delivered to.

# %%
df['Purchase Address'].str.split(',')
# Out:
# 0                 [944 Walnut St,  Boston,  MA 02215]
# 1                [185 Maple St,  Portland,  OR 97035]
# 2           [538 Adams St,  San Francisco,  CA 94016]
# 3              [738 10th St,  Los Angeles,  CA 90001]
# 4                   [387 10th St,  Austin,  TX 73301]
#                              ...
# 373695     [840 Highland St,  Los Angeles,  CA 90001]
# 373696    [216 Dogwood St,  San Francisco,  CA 94016]
# 373697       [220 12th St,  San Francisco,  CA 94016]
# 373698     [511 Forest St,  San Francisco,  CA 94016]
# 373699     [250 Meadow St,  San Francisco,  CA 94016]
# Name: Purchase Address, Length: 373700, dtype: object

# %%
df[['Street', 'City', 'State']] = df['Purchase Address'].str.split(',', expand=True)

# %%
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 373695   259353    AAA Batteries (4-pack)                3       2.99
# 373696   259354                    iPhone                1        700
# 373697   259355                    iPhone                1        700
# 373698   259356    34in Ultrawide Monitor                1     379.99
# 373699   259357      USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373700 entries, 0 to 373699
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          372610 non-null  object
#  1   Product           372610 non-null  object
#  2   Quantity Ordered  372610 non-null  object
#  3   Price Each        372610 non-null  object
#  4   Order Date        372610 non-null  object
#  5   Purchase Address  372610 non-null  object
#  6   Street            372610 non-null  object
#  7   City              371900 non-null  object
#  8   State             371900 non-null  object
# dtypes: object(9)
# memory usage: 25.7+ MB

# %%
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address         Street  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215  944 Walnut St
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035   185 Maple St
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016   538 Adams St
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001    738 10th St
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301    387 10th St
#
#              City      State
# 0          Boston   MA 02215
# 1        Portland   OR 97035
# 2   San Francisco   CA 94016
# ...

# %%
df.isnull().sum()
# Out:
# Order ID            1090
# Product             1090
# Quantity Ordered    1090
# Price Each          1090
# Order Date          1090
# Purchase Address    1090
# Street              1090
# City                1800
# State               1800
# dtype: int64

# %%
df.drop(labels=["Purchase Address", "Street", "State"], axis=1, inplace=True)

# %%
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 373695   259353    AAA Batteries (4-pack)                3       2.99
# 373696   259354                    iPhone                1        700
# 373697   259355                    iPhone                1        700
# 373698   259356    34in Ultrawide Monitor                1     379.99
# 373699   259357      USB-C Charging Cable                1      11.95
#
#             Order Date            City
# 0       01/22/19 21:25          Boston
# 1       01/28/19 14:15        Portland
# ...

# %%
df.isnull().sum()
# Out:
# Order ID            1090
# Product             1090
# Quantity Ordered    1090
# Price Each          1090
# Order Date          1090
# City                1800
# dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date            City
# 0  01/22/19 21:25          Boston
# 1  01/28/19 14:15        Portland
# 2  01/17/19 13:33   San Francisco
# 3  01/05/19 20:33     Los Angeles
# 4  01/25/19 11:59          Austin

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# City                0
# dtype: int64

# %%
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        141234                    iPhone                1        700
# 1        141235  Lightning Charging Cable                1      14.95
# 2        141236          Wired Headphones                2      11.99
# 3        141237          27in FHD Monitor                1     149.99
# 4        141238          Wired Headphones                1      11.99
# ...         ...                       ...              ...        ...
# 373695   259353    AAA Batteries (4-pack)                3       2.99
# 373696   259354                    iPhone                1        700
# 373697   259355                    iPhone                1        700
# 373698   259356    34in Ultrawide Monitor                1     379.99
# 373699   259357      USB-C Charging Cable                1      11.95
#
#             Order Date            City
# 0       01/22/19 21:25          Boston
# 1       01/28/19 14:15        Portland
# ...

# %%
df.describe()
# Out:
#        Order ID               Product Quantity Ordered Price Each  \
# count    371900                371900           371900     371900
# unique   178437                    19                9         23
# top      160873  USB-C Charging Cable                1      11.95
# freq         10                 43806           337104      43806
#
#             Order Date            City
# count           371900          371900
# unique          142395               9
# top     12/15/19 20:16   San Francisco
# freq                16           89464

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371900 entries, 0 to 373699
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          371900 non-null  object
#  1   Product           371900 non-null  object
#  2   Quantity Ordered  371900 non-null  object
#  3   Price Each        371900 non-null  object
#  4   Order Date        371900 non-null  object
#  5   City              371900 non-null  object
# dtypes: object(6)
# memory usage: 19.9+ MB

# %%
df["Order Date"]=pd.to_datetime(df["Order Date"], errors="coerce")

# %%
df["Price Each"]=pd.to_numeric(df["Price Each"], errors="coerce")

# %%
df["Order ID"]=pd.to_numeric(df["Order ID"], errors="coerce")
df["Quantity Ordered"]=pd.to_numeric(df["Quantity Ordered"], errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 371900 entries, 0 to 373699
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          371900 non-null  int64
#  1   Product           371900 non-null  object
#  2   Quantity Ordered  371900 non-null  int64
#  3   Price Each        371900 non-null  float64
#  4   Order Date        371900 non-null  datetime64[ns]
#  5   City              371900 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 19.9+ MB

# %%
df.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0    141234                    iPhone                 1      700.00
# 1    141235  Lightning Charging Cable                 1       14.95
# 2    141236          Wired Headphones                 2       11.99
# 3    141237          27in FHD Monitor                 1      149.99
# 4    141238          Wired Headphones                 1       11.99
#
#            Order Date            City
# 0 2019-01-22 21:25:00          Boston
# 1 2019-01-28 14:15:00        Portland
# 2 2019-01-17 13:33:00   San Francisco
# 3 2019-01-05 20:33:00     Los Angeles
# 4 2019-01-25 11:59:00          Austin

# %%
df["Day"]=df["Order Date"].dt.day

# %%
df["Month"]=df["Order Date"].dt.month

# %%
df["Year"]=df["Order Date"].dt.year
df["Hour"]=df["Order Date"].dt.hour
df["Minute"]=df["Order Date"].dt.minute

# %%
df.drop("Order Date", inplace=True, axis=1)

# %%
df
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 0         141234                    iPhone                 1      700.00
# 1         141235  Lightning Charging Cable                 1       14.95
# 2         141236          Wired Headphones                 2       11.99
# 3         141237          27in FHD Monitor                 1      149.99
# 4         141238          Wired Headphones                 1       11.99
# ...          ...                       ...               ...         ...
# 373695    259353    AAA Batteries (4-pack)                 3        2.99
# 373696    259354                    iPhone                 1      700.00
# 373697    259355                    iPhone                 1      700.00
# 373698    259356    34in Ultrawide Monitor                 1      379.99
# 373699    259357      USB-C Charging Cable                 1       11.95
#
#                   City  Day  Month  Year  Hour  Minute
# ...

# %%
df["Sales"]=df["Quantity Ordered"]*df["Price Each"]

# %%
df
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 0         141234                    iPhone                 1      700.00
# 1         141235  Lightning Charging Cable                 1       14.95
# 2         141236          Wired Headphones                 2       11.99
# 3         141237          27in FHD Monitor                 1      149.99
# 4         141238          Wired Headphones                 1       11.99
# ...          ...                       ...               ...         ...
# 373695    259353    AAA Batteries (4-pack)                 3        2.99
# 373696    259354                    iPhone                 1      700.00
# 373697    259355                    iPhone                 1      700.00
# 373698    259356    34in Ultrawide Monitor                 1      379.99
# 373699    259357      USB-C Charging Cable                 1       11.95
#
#                   City  Day  Month  Year  Hour  Minute   Sales
# ...

# %%
pd.pivot_table(index="Month", columns="City", values="Sales", data=df, aggfunc=sum)
# Out:
# City     Atlanta     Austin      Boston     Dallas   Los Angeles  \
# Month
# 1      298319.08  176174.12   402176.98  286925.02     577203.80
# 2      352940.60  217574.80   429616.72  373335.98     684123.32
# 3      463810.76  309098.54   602047.62  444753.36     859858.74
# 4      568897.82  345367.18   707614.22  502720.96    1100528.04
# 5      477707.98  321270.44   657607.30  536912.98     999378.42
# 6      439632.94  288114.58   509495.78  373771.50     903063.86
# 7      423532.94  300649.86   582994.28  424650.34     788669.28
# 8      338535.32  251427.22   478550.52  359526.92     691787.00
# 9      342557.78  212967.40   496817.46  328425.72     708151.38
# 10     612586.02  406392.24   734072.78  646271.20    1224906.50
# 11     550677.40  342572.94   703092.04  497219.12     999381.58
# 12     721798.52  467554.18  1019198.32  761437.70    1368089.68
#
# City    New York City   Portland   San Francisco    Seattle
# Month
# ...

# %%
g_city=df.groupby(["City"])["Sales"].sum().round()

# %%
g_city
# Out:
# City
#  Atlanta           5590997.0
#  Austin            3639164.0
#  Boston            7323284.0
#  Dallas            5535951.0
#  Los Angeles      10905142.0
#  New York City     9328635.0
#  Portland          4640981.0
#  San Francisco    16524408.0
#  Seattle           5495511.0
# Name: Sales, dtype: float64

# %%
g_city.plot(kind="bar", figsize=(15, 10), color=["red", "blue"])
plt.xlabel(["City"])
plt.ylabel(["Sales"])
# Out:
# Text(0, 0.5, "['Sales']")

# %% [markdown]
# #San Francisco has highest sales

# %%
sns.barplot(x="Month", y="Sales", data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Sales'>

# %% [markdown]
# #june and july have the highest amount of sales

# %%
df.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0    141234                    iPhone                 1      700.00
# 1    141235  Lightning Charging Cable                 1       14.95
# 2    141236          Wired Headphones                 2       11.99
# 3    141237          27in FHD Monitor                 1      149.99
# 4    141238          Wired Headphones                 1       11.99
#
#              City  Day  Month  Year  Hour  Minute   Sales
# 0          Boston   22      1  2019    21      25  700.00
# 1        Portland   28      1  2019    14      15   14.95
# 2   San Francisco   17      1  2019    13      33   23.98
# 3     Los Angeles    5      1  2019    20      33  149.99
# 4          Austin   25      1  2019    11      59   11.99

# %%
max_month=df.groupby(["Month"])["Sales"].sum().round().sort_values(ascending=False)

# %%
max_month
# Out:
# Month
# 12    9226887.0
# 10    7473454.0
# 4     6781340.0
# 11    6399206.0
# 5     6305214.0
# 3     5614201.0
# 7     5295552.0
# 6     5155605.0
# 8     4488936.0
# 2     4404045.0
# 9     4195120.0
# 1     3644513.0
# Name: Sales, dtype: float64

# %%
max_month.plot(kind="bar", figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
most_products=pd.crosstab(df["City"],df["Product"])

# %%
most_products
# Out:
# Product         20in Monitor  27in 4K Gaming Monitor  27in FHD Monitor  \
# City
#  Atlanta                 676                     984              1168
#  Austin                  456                     636               712
#  Boston                  788                    1346              1586
#  Dallas                  680                     958              1160
#  Los Angeles            1308                    2006              2434
#  New York City          1110                    1680              2138
#  Portland                554                     866              1056
#  San Francisco          1986                    2912              3606
#  Seattle                 644                    1072              1154
#
# Product         34in Ultrawide Monitor  AA Batteries (4-pack)  \
# City
#  Atlanta                           956                   3322
#  Austin                            656                   2142
# ...

# %%
df["Product"].nunique()
# Out:
# 19

# %%
plt.figure(figsize=(25,18))
sns.countplot(x="City", hue="Product", data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
df.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0    141234                    iPhone                 1      700.00
# 1    141235  Lightning Charging Cable                 1       14.95
# 2    141236          Wired Headphones                 2       11.99
# 3    141237          27in FHD Monitor                 1      149.99
# 4    141238          Wired Headphones                 1       11.99
#
#              City  Day  Month  Year  Hour  Minute   Sales
# 0          Boston   22      1  2019    21      25  700.00
# 1        Portland   28      1  2019    14      15   14.95
# 2   San Francisco   17      1  2019    13      33   23.98
# 3     Los Angeles    5      1  2019    20      33  149.99
# 4          Austin   25      1  2019    11      59   11.99

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x="Hour", y="Sales", data=df)
plt.title("Sales throughout the day")
# Out:
# Text(0.5, 1.0, 'Sales throughout the day')

# %% [markdown]
# #At 1am, its having the maximum sales.

# %%
morning=df[(df["Hour"]>6.0)&(df["Hour"]<12.0)].replace("Morning")

# %%
morning
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 4         141238            Wired Headphones                 1       11.99
# 8         141242  Bose SoundSport Headphones                 1       99.99
# 10        141244    Apple Airpods Headphones                 1      150.00
# 11        141245          Macbook Pro Laptop                 1     1700.00
# 16        141250             Vareebadd Phone                 1      400.00
# ...          ...                         ...               ...         ...
# 373668    259328            Wired Headphones                 1       11.99
# 373671    259331    Apple Airpods Headphones                 1      150.00
# 373674    259334        USB-C Charging Cable                 1       11.95
# 373688    259347       AA Batteries (4-pack)                 1        3.84
# 373697    259355                      iPhone                 1      700.00
#
#                   City  Day  Month  Year  Hour  Minute    Sales
# ...

# %%
sns.lineplot(x="Hour", y="Sales", data=morning)
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Sales'>

# %%
products_morning=morning.groupby(["Product"])["Sales"].sum().sort_values()

# %%
products_morning
# Out:
# Product
# AAA Batteries (4-pack)          43038.06
# AA Batteries (4-pack)           47984.64
# Wired Headphones               112610.08
# USB-C Charging Cable           131808.50
# LG Washing Machine             157200.00
# Lightning Charging Cable       159307.20
# LG Dryer                       174000.00
# 20in Monitor                   203701.48
# Vareebadd Phone                378400.00
# 27in FHD Monitor               496166.92
# Bose SoundSport Headphones     615738.42
# Flatscreen TV                  650400.00
# 34in Ultrawide Monitor        1048772.40
# Apple Airpods Headphones      1077000.00
# 27in 4K Gaming Monitor        1077152.38
# Google Phone                  1527600.00
# ThinkPad Laptop               1871981.28
# iPhone                        2200800.00
# Macbook Pro Laptop            3668600.00
# Name: Sales, dtype: float64

# %%
afternoon=df[(df["Hour"]>=12.0)&(df["Hour"]<18.0)]
afternoon
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 1         141235  Lightning Charging Cable                 1       14.95
# 2         141236          Wired Headphones                 2       11.99
# 6         141240    27in 4K Gaming Monitor                 1      389.99
# 7         141241      USB-C Charging Cable                 1       11.95
# 15        141249          27in FHD Monitor                 1      149.99
# ...          ...                       ...               ...         ...
# 373691    259350              Google Phone                 1      600.00
# 373692    259350      USB-C Charging Cable                 1       11.95
# 373694    259352      USB-C Charging Cable                 1       11.95
# 373696    259354                    iPhone                 1      700.00
# 373698    259356    34in Ultrawide Monitor                 1      379.99
#
#                   City  Day  Month  Year  Hour  Minute   Sales
# ...

# %%
sns.lineplot(x="Hour", y="Sales", data=afternoon)
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Sales'>

# %%
products_afternoon=afternoon.groupby(["Product"])["Sales"].sum().sort_values(ascending=False)

# %%
products_afternoon
# Out:
# Product
# Macbook Pro Laptop            5865000.00
# iPhone                        3439800.00
# ThinkPad Laptop               3053969.46
# Google Phone                  2353200.00
# 27in 4K Gaming Monitor        1760414.86
# 34in Ultrawide Monitor        1714514.88
# Apple Airpods Headphones      1682400.00
# Flatscreen TV                 1067400.00
# Bose SoundSport Headphones     973502.64
# 27in FHD Monitor               833644.42
# Vareebadd Phone                597600.00
# 20in Monitor                   338109.26
# LG Washing Machine             316800.00
# LG Dryer                       288000.00
# Lightning Charging Cable       251249.70
# USB-C Charging Cable           204846.90
# Wired Headphones               179178.56
# AA Batteries (4-pack)           77268.48
# AAA Batteries (4-pack)          65893.62
# Name: Sales, dtype: float64

# %%
products_afternoon.plot(kind="bar", figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Product'>

# %%
evening=df[(df["Hour"]>=18.0)&(df["Hour"]<=24.0)]
evening
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 0         141234                    iPhone                 1      700.00
# 3         141237          27in FHD Monitor                 1      149.99
# 5         141239    AAA Batteries (4-pack)                 1        2.99
# 9         141243  Apple Airpods Headphones                 1      150.00
# 12        141246    AAA Batteries (4-pack)                 3        2.99
# ...          ...                       ...               ...         ...
# 373686    259345           ThinkPad Laptop                 1      999.99
# 373689    259348  Lightning Charging Cable                 1       14.95
# 373690    259349    AAA Batteries (4-pack)                 1        2.99
# 373693    259351  Apple Airpods Headphones                 1      150.00
# 373695    259353    AAA Batteries (4-pack)                 3        2.99
#
#                   City  Day  Month  Year  Hour  Minute   Sales
# ...

# %%
night=df[(df["Hour"]>0.0)&(df["Hour"]<=6.0)]
night
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 83        141315      USB-C Charging Cable                 1       11.95
# 95        141327      USB-C Charging Cable                 1       11.95
# 102       141334      USB-C Charging Cable                 1       11.95
# 125       141357  Lightning Charging Cable                 1       14.95
# 131       141363          Wired Headphones                 1       11.99
# ...          ...                       ...               ...         ...
# 373589    259256      USB-C Charging Cable                 2       11.95
# 373599    259266      USB-C Charging Cable                 1       11.95
# 373605    259271             Flatscreen TV                 1      300.00
# 373630    259295     AA Batteries (4-pack)                 1        3.84
# 373645    259306  Apple Airpods Headphones                 1      150.00
#
#                   City  Day  Month  Year  Hour  Minute   Sales
# ...

# %%
mor=morning["Sales"].sum()
aft=afternoon["Sales"].sum().round(0)
eve=evening["Sales"].sum()
nig=night["Sales"].sum()

# %%
mor
aft
eve
nig
# Out:
# 3365860.08

# %%
mor
# Out:
# 15642261.36

# %%
aft
# Out:
# 25062793.0

# %%
eve
# Out:
# 23485715.18

# %%
nig
# Out:
# 3365860.08

# %%
group=pd.DataFrame({"morning":mor,"afternoon":aft, "evening":eve, "night":nig},index=["Accuracy"]),

# %%
group
# Out:
# (              morning   afternoon      evening       night
#  Accuracy  15642261.36  25062793.0  23485715.18  3365860.08,)

# %%
p=pd.DataFrame(group)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [223], in <cell line: 1>()
# ----> 1 p=pd.DataFrame(group)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:737, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     729         mgr = arrays_to_mgr(
#     730             arrays,
#     731             columns,
#    (...)
#     734             typ=manager,
#     735         )
#     736     else:
# --> 737         mgr = ndarray_to_mgr(
#     738             data,
#     739             index,
#     740             columns,
#     741             dtype=dtype,
#     742             copy=copy,
#     743             typ=manager,
#     744         )
#     745 else:
#     746     mgr = dict_to_mgr(
#     747         {},
#     748         index,
#    (...)
#     751         typ=manager,
#     752     )
#
# ...

# %%
df=df[df["Order ID"].duplicated(keep=False)]
#checking the product with the same IDs

# %%
df
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 0         141234                    iPhone                 1      700.00
# 1         141235  Lightning Charging Cable                 1       14.95
# 2         141236          Wired Headphones                 2       11.99
# 3         141237          27in FHD Monitor                 1      149.99
# 4         141238          Wired Headphones                 1       11.99
# ...          ...                       ...               ...         ...
# 373695    259353    AAA Batteries (4-pack)                 3        2.99
# 373696    259354                    iPhone                 1      700.00
# 373697    259355                    iPhone                 1      700.00
# 373698    259356    34in Ultrawide Monitor                 1      379.99
# 373699    259357      USB-C Charging Cable                 1       11.95
#
#                   City  Day  Month  Year  Hour  Minute   Sales
# ...

# %%
df1
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 0         141234                    iPhone                 1      700.00
# 1         141235  Lightning Charging Cable                 1       14.95
# 2         141236          Wired Headphones                 2       11.99
# 3         141237          27in FHD Monitor                 1      149.99
# 4         141238          Wired Headphones                 1       11.99
# ...          ...                       ...               ...         ...
# 373695    259353    AAA Batteries (4-pack)                 3        2.99
# 373696    259354                    iPhone                 1      700.00
# 373697    259355                    iPhone                 1      700.00
# 373698    259356    34in Ultrawide Monitor                 1      379.99
# 373699    259357      USB-C Charging Cable                 1       11.95
#
#                   City  Day  Month  Year  Hour  Minute   Sales
# ...

# %%
df1=df.drop_duplicates(keep="first")

# %%
df1
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone                 1      700.00
# 1         141235    Lightning Charging Cable                 1       14.95
# 2         141236            Wired Headphones                 2       11.99
# 3         141237            27in FHD Monitor                 1      149.99
# 4         141238            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 186845    319666    Lightning Charging Cable                 1       14.95
# 186846    319667       AA Batteries (4-pack)                 2        3.84
# 186847    319668             Vareebadd Phone                 1      400.00
# 186848    319669            Wired Headphones                 1       11.99
# 186849    319670  Bose SoundSport Headphones                 1       99.99
#
#                   City  Day  Month  Year  Hour  Minute   Sales
# ...

# %%
df2=df1[df1["Order ID"].duplicated(keep=False)]

# %%
df2
# Out:
#         Order ID                   Product  Quantity Ordered  Price Each  \
# 41        141275      USB-C Charging Cable                 1       11.95
# 42        141275          Wired Headphones                 1       11.99
# 57        141290  Apple Airpods Headphones                 1      150.00
# 58        141290     AA Batteries (4-pack)                 3        3.84
# 133       141365           Vareebadd Phone                 1      400.00
# ...          ...                       ...               ...         ...
# 186761    319584          Wired Headphones                 1       11.99
# 186773    319596                    iPhone                 1      700.00
# 186774    319596  Lightning Charging Cable                 1       14.95
# 186809    319631    34in Ultrawide Monitor                 1      379.99
# 186810    319631  Lightning Charging Cable                 1       14.95
#
#                   City  Day  Month  Year  Hour  Minute   Sales
# ...

# %%
df2["Pair Together"]=df2.groupby("Order ID")["Product"].transform(lambda x:", ".join(x))
# Out:
# C:\Users\sharan\AppData\Local\Temp\ipykernel_27340\3779797988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Pair Together"]=df2.groupby("Order ID")["Product"].transform(lambda x:", ".join(x))

# %%
df2["Pair Together"]
# Out:
# 41                  USB-C Charging Cable, Wired Headphones
# 42                  USB-C Charging Cable, Wired Headphones
# 57         Apple Airpods Headphones, AA Batteries (4-pack)
# 58         Apple Airpods Headphones, AA Batteries (4-pack)
# 133                      Vareebadd Phone, Wired Headphones
#                                 ...
# 186761                            iPhone, Wired Headphones
# 186773                    iPhone, Lightning Charging Cable
# 186774                    iPhone, Lightning Charging Cable
# 186809    34in Ultrawide Monitor, Lightning Charging Cable
# 186810    34in Ultrawide Monitor, Lightning Charging Cable
# Name: Pair Together, Length: 14128, dtype: object

# %%
df2[["Order ID", "Pair Together"]]
# Out:
#         Order ID                                     Pair Together
# 41        141275            USB-C Charging Cable, Wired Headphones
# 42        141275            USB-C Charging Cable, Wired Headphones
# 57        141290   Apple Airpods Headphones, AA Batteries (4-pack)
# 58        141290   Apple Airpods Headphones, AA Batteries (4-pack)
# 133       141365                 Vareebadd Phone, Wired Headphones
# ...          ...                                               ...
# 186761    319584                          iPhone, Wired Headphones
# 186773    319596                  iPhone, Lightning Charging Cable
# 186774    319596                  iPhone, Lightning Charging Cable
# 186809    319631  34in Ultrawide Monitor, Lightning Charging Cable
# 186810    319631  34in Ultrawide Monitor, Lightning Charging Cable
#
# [14128 rows x 2 columns]

# %%
df2["Pair Together"].value_counts()
# Out:
# iPhone, Lightning Charging Cable              1772
# Google Phone, USB-C Charging Cable            1714
# iPhone, Wired Headphones                       722
# Vareebadd Phone, USB-C Charging Cable          624
# Google Phone, Wired Headphones                 606
#                                               ...
# 27in FHD Monitor, Vareebadd Phone                2
# LG Washing Machine, AA Batteries (4-pack)        2
# LG Washing Machine, iPhone                       2
# 20in Monitor, Flatscreen TV                      2
# LG Washing Machine, 27in 4K Gaming Monitor       2
# Name: Pair Together, Length: 350, dtype: int64

# %% [markdown]
# #iPhone and Lightining charging cable are the highest
