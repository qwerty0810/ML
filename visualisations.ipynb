# %%
#matplotlib: it is a python 2D plotting library. it produces quality figures in a variety of formats and interactive environments
#matplotlib.pyplot is a collection of command style fucntions. Each pyplot function makes some changes to a figure.
#example: creating plotting area, decorating the plots with labels etc.

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(4,3,"*")

# %%
import numpy as np
import pandas as pd

# %%
x=np.array([2,4,6,8,10,12,14,16])
y=x/2
plt.scatter(x,y, c="red")

# %%
plt.plot(x,y,c="green")
plt.xlabel("Horizontal")
plt.ylabel("Vertical")
# Out:
# Text(0, 0.5, 'Vertical')

# %%
names=["Class 1","Class 2","Class 3","Class 4","Class 5"]
scores=[10,20,30,40,50]
plt.figure(figsize=(15,8))
plt.subplot(131)
plt.bar(names,scores)
plt.subplot(132)
plt.scatter(names, scores)
plt.subplot(133)
plt.plot(names,scores)
plt.suptitle("Categorical Plotting")
plt.xlabel("Classes")
plt.xlabel("Classes")
plt.show()

# %%
#seaborn: comes with a large number of high level interfaces and customized themes that matplotlib lacks
#seaborn works on top of matplotlib

# %%
df=pd.read_csv("Pokemon.csv")

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
import seaborn as sns

# %%
sns.stripplot(df["Generation"],df["Attack"])
# Out:
# C:\Users\sharan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Generation', ylabel='Attack'>

# %%
sns.scatterplot(x="Attack",y="Defense",data=df)
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Defense'>

# %%
sns.lmplot(x="Attack",y="Defense",data=df)

# %%
sns.lmplot(x="Attack",y="Defense",data=df,fit_reg=False, hue="Generation")

# %%
#hue argument is very useful because it allows you to express a third dimension of information using color.

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.drop(["Name","Type 1","Type 2", "Legendary"], axis=1, inplace=True)

# %%
df
# Out:
#        #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      1    318  45      49       49       65       65     45           1
# 1      2    405  60      62       63       80       80     60           1
# 2      3    525  80      82       83      100      100     80           1
# 3      3    625  80     100      123      122      120     80           1
# 4      4    309  39      52       43       60       50     65           1
# ..   ...    ...  ..     ...      ...      ...      ...    ...         ...
# 795  719    600  50     100      150      100      150     50           6
# 796  719    700  50     160      110      160      110    110           6
# 797  720    600  80     110       60      150      130     70           6
# 798  720    680  80     160       60      170      130     80           6
# 799  721    600  80     110      120      130       90     70           6
#
# [800 rows x 9 columns]

# %%
sns.boxplot(df["Attack"])
# Out:
# <AxesSubplot:xlabel='Attack'>

# %%
sns.boxplot(df["Defense"])
# Out:
# C:\Users\sharan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Defense'>

# %%
df.head()
# Out:
#    #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0  1    318  45      49       49       65       65     45           1
# 1  2    405  60      62       63       80       80     60           1
# 2  3    525  80      82       83      100      100     80           1
# 3  3    625  80     100      123      122      120     80           1
# 4  4    309  39      52       43       60       50     65           1

# %%
df.drop(["#","Generation","Total"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0  45      49       49       65       65     45
# 1  60      62       63       80       80     60
# 2  80      82       83      100      100     80
# 3  80     100      123      122      120     80
# 4  39      52       43       60       50     65

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   HP       800 non-null    int64
#  1   Attack   800 non-null    int64
#  2   Defense  800 non-null    int64
#  3   Sp. Atk  800 non-null    int64
#  4   Sp. Def  800 non-null    int64
#  5   Speed    800 non-null    int64
# dtypes: int64(6)
# memory usage: 37.6 KB

# %%
sns.distplot(df["Defense"])
# Out:
# C:\Users\sharan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Defense', ylabel='Density'>

# %%
sns.distplot(df["Sp. Atk"], kde=False)
# Out:
# C:\Users\sharan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sp. Atk'>

# %%
sns.kdeplot(df["Defense"], shade=True)
# Out:
# <AxesSubplot:xlabel='Defense', ylabel='Density'>

# %%
sns.jointplot(df["Defense"],df["Sp. Atk"])

# %%
sns.jointplot(df["Defense"],df["Sp. Atk"], kind="reg")
# Out:
# C:\Users\sharan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(data=df)

# %%
sns.violinplot(df["Speed"])
# Out:
# C:\Users\sharan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Speed'>

# %%
sns.stripplot(df["Defense"],df["Attack"])
# Out:
# C:\Users\sharan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Defense', ylabel='Attack'>

# %%
df.head()
# Out:
#    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0  45      49       49       65       65     45
# 1  60      62       63       80       80     60
# 2  80      82       83      100      100     80
# 3  80     100      123      122      120     80
# 4  39      52       43       60       50     65
